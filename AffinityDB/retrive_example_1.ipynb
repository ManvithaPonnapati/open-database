# %%
from retrive import retrive_data
# Out:
# connect to /home/xander/affinityDB/test_t/affinity.db

# %% [markdown]
# ### create a class to retrive data

# %%
ra = retrive_data()

# %% [markdown]
# ### Set receptor
# Load the information for splited receptors from table 2

# %%
ra.receptor(2)

# %% [markdown]
# ### Set ligand
# Get the information for reordered ligand from table 3

# %%
ra.crystal(3)

# %% [markdown]
# ### Select ligand by affinity
# Get the information for binding affintiy from table 9
#
# select the ligand with log binding affinity value in [-30, -20]
#
# ### rest
# - tuple: (a,b) , restriction a < value < b
# - list: [a,b] , restriction a <= value <= b
# - None: no restriction

# %%
ra.log_affinity(9, rest=[-30,-20])

# %% [markdown]
# ### export
# export the selected ligand as pandas dataframe

# %%
db_table = ra.export_table()

# %%
db_table
# Out:
#    receptor chain resnum resname  log_affinity
# 0      1MUI     B    100     AB1    -27.368657
# 1      1LF9     A    700     ACR    -27.631021
# 2      2C1Q     A   1126     BTN    -29.933606
# 3      2GH7     B   5200     BTN    -29.933606
# 4      1DUV     H    402     PSQ    -27.161017
# 5      1NDJ     D   5400     BTN    -28.002085
# 6      1CTU     A    295     ZEB    -27.448700
# 7      1NDJ     A   5100     BTN    -28.002085
# 8      1SWK     D   5400     BTN    -27.631021
# 9      2F01     B   5200     BTN    -29.933606
# 10     4WKC     A    301     BIG    -29.191669
# 11     5BRY     B    201     4UY    -27.225556
# 12     3O9H     B    200     K2E    -27.854165
# 13     2ZX5     B    902     ZX5    -28.388174
# 14     2UYW     D   1124     BTN    -29.933606
# 15     1Q83     B   1952     TZ5    -28.522619
# 16     1Q83     A   1951     TZ5    -28.522619
# 17     2XUP     A   1548     TZ5    -28.522619
# 18     1SWK     A   5100     BTN    -27.631021
# 19     4F3C     B    301     BIG    -27.225556
# 20     1GAH     A    497     ACR    -27.631021
# 21     4DFG     B    201     0JV    -27.043234
# 22     1RBO     B    476     CAP    -29.291752
# 23     3O9B     A    200     K2A    -28.324168
# 24     2XUP     B   1545     TZ5    -28.522619
# 25     1A4M     D   1854     PRH    -29.933606
# 26     1AGM     A    495     ACR    -27.631021
# 27     1SWN     A    300     BTN    -27.631021
# 28     1DUV     G    401     PSQ    -27.161017
# 29     1SL3     A   1001     170    -27.294549
# 30     1A4M     C   1354     PRH    -29.933606
# 31     2GH7     A   5100     BTN    -29.933606
# 32     3O9I     A    200     A61    -27.225556
# 33     1SWN     C    500     BTN    -27.631021
# 34     1SWK     B   5200     BTN    -27.631021
# 35     4F3C     A    301     BIG    -27.225556
# 36     2F01     A   5100     BTN    -29.933606
# 37     2UYW     A   1123     BTN    -29.933606
# 38     1RBO     E    476     CAP    -29.291752
# 39     1SWN     D    600     BTN    -27.631021
# 40     4N70     A    401     2HX    -27.631021
# 41     1A4M     A    354     PRH    -29.933606
# 42     1A4M     B    854     PRH    -29.933606
# 43     3O9C     A    200     K20    -27.736382
# 44     1LF9     B    701     ACR    -27.631021
# 45     3O9F     A    200     K2D    -29.240459
# 46     2ZX5     A    901     ZX5    -28.388174
# 47     1RBO     L    476     CAP    -29.291752
# 48     1NDJ     C   5300     BTN    -28.002085
# 49     2ADA     A    353     HPR    -29.933606
# 50     1RBO     H    476     CAP    -29.291752
# 51     1DUV     I    403     PSQ    -27.161017
# 52     3O9G     A    200     F53    -28.324168
# 53     2I0D     A    200     MUT    -27.854165
# 54     1NDJ     B   5200     BTN    -28.002085
